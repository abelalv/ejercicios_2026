# %% [markdown]
# # Taller de de algebra lineal
#
# **Antes de comenzar realiza  una copia de este cuaderno en tu google drive, para esto ve a `Archivo` > `Hacer una copia` y guarda el cuaderno con el nombre que quieras.**
#
# Lea atentamente las instrucciones y resuelva los ejercicios propuestos. Recuerde que el objetivo de este taller es aplicar los conceptos aprendidos en clase, por lo que es importante que intente resolver los ejercicios por su cuenta. Además, para las cuentas debe usar el cuaderno de google colab y la librería de **numpy**, no se permite el uso de calculadoras o software adicional.
#
# Al finalizar el taller debe subir el cuaderno con sus respuestas a la plataforma de la clase. Asegúrese de que su cuaderno esté completo y bien organizado, con todas las respuestas claramente indicadas.

# %%
## Recuerde que para sumar dos vectores se usa la librería NumPy, y se pueden sumar directamente con el operador `+` o usando la función `np.add()`. Para multiplicar un vector por un escalar, se puede usar el operador `*` o la función `np.multiply()`. Para calcular el producto punto entre dos vectores, se puede usar la función `np.dot()` o el método `.dot()` de los arrays de NumPy.

import numpy as np

a = np.array([1, 2])
b = np.array([3, 4])
# Suma de vectores
suma = a + b
# Multiplicación por escalar
escalar = 2
multiplicacion = escalar * a
# Producto punto
producto_punto = np.dot(a, b)
print("Suma:", suma)
print("Multiplicación por escalar:", multiplicacion)
print("Producto punto:", producto_punto)

# %% [markdown]
# # Problema
#
# Año 2045. La inteligencia artificial "Aegis" ha bloqueado el acceso a los servidores centrales de la ciudad. Tu equipo de élite ha logrado introducir un micro-drone programable en los ductos de ventilación del núcleo de datos.
#
# El drone se mueve en un plano bidimensional $(\mathbb{R}^2)$ y solo puede desplazarse usando dos propulsores específicos (motores vectoriales). Para evitar ser detectado por los sensores de calor, el drone debe seguir trayectorias precisas y mantener distancias de seguridad respecto a los láseres de vigilancia.

# %% [markdown]
# ```
# ╔═════════════════════════════════════════════════════════════╗
# ║  ⚠️  ALERTA NIVEL ROJO — Necesitamos a super amigos ⚠️      ║
# ║                                                             ║
# ║    ¿con tu drone MD-1 podrás llegar a la terminal $T$?      ║
# ╚═════════════════════════════════════════════════════════════╝
# ```

# %% [markdown]
# ### 1. El Sistema de Propulsión (Motores)
# El drone MD-1 solo puede desplazarse usando dos propulsores que funcionan como vectores en el plano $\mathbb{R}^2$:
# * **Motor A (Vector $\vec{u}$):** $(3, 1)$
# * **Motor B (Vector $\vec{v}$):** $(1, 2)$
#
# ### 2. El Objetivo
# La terminal de datos (Punto $T$) se encuentra en las coordenadas $(11, 7)$.
#
# ### 3. La Amenaza (El Láser)
# Hay un láser de seguridad que sigue una **recta paramétrica**. El láser pasa por el punto $P = (0, 5)$ y se extiende en la dirección del vector $\vec{d} = (4, 1)$.
#
# ---
# ### 🛠️ Tu Tarea Debes justificar tus respuestas:
# 1.  **Verificar** si el drone puede llegar a cualquier punto del servidor.
# 2.  **Calcular** cuánto tiempo debe encenderse cada motor para llegar exactamente a la terminal $T$
# 3.   **Seguridad:** Determinar la distancia más corta entre la terminal $T$ y el láser de seguridad para saber si la conexión es estable.
# 4.   Para los calculos, utiliza el cuaderno de google colab y la librería de **numpy**. No se permite el uso de calculadoras o software adicional.
